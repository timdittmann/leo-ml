# %%
import xarray as xr
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal 
from sklearn.decomposition import PCA
import argparse
import pandas as pd

import sys  
sys.path.insert(1, '/home/stdi2687/gnss-leo-data/scripts')

from feature_extract_util import *

# %%
'''
ie = 1 = e region ionospheric scintillation
if = 2 = f region is
n =  3 = NO disturbance
o =  4 = oscillator anomoly
r1 =  5 = L1 rfi
r2 = 6 = L2 rfi
r = 7 = L1 + L2 RFI
a = 8 = suspected tracking/processing artifact
l = 9 = low SNR
d = 10 = unknown disturbance
'''
def class_map_binary(y):
    y_new=np.empty(len(y))
    y_new[y==1]=0
    y_new[y==2]=0
    y_new[y==3]=0
    y_new[y==4]=0
    y_new[y==5]=1
    y_new[y==6]=1
    y_new[y==7]=1
    y_new[y==8]=0
    y_new[y==9]=0
    y_new[y==10]=0
    return y_new

def class_map_multi(y):
    y_new=np.empty(len(y))
    y_new[y==1]=1
    y_new[y==2]=1
    y_new[y==3]=3
    y_new[y==4]=0
    y_new[y==5]=0
    y_new[y==6]=0
    y_new[y==7]=0
    y_new[y==8]=0
    y_new[y==9]=2
    y_new[y==10]=0
    return y_new

def get_meta_drop(df):
    times=df['time'].values
    lats=df["lat_m"].values
    occ_hts=df['occheight_m'].values
    X=df.loc[:, df.columns != 'y_'].drop(columns=['time', 'lat_m','occheight_m']).values
    feature_names=df.loc[:, df.columns != 'y_'].drop(columns=['time', 'lat_m','occheight_m']).columns
    return X, feature_names, times, lats, occ_hts

def df_2_Xy(df):
    #drop_cols=['time2', 'rfi_max','lat_m', 'lon_m', 'elevation_m', 'occheight_m','slip_L1', 'slip_L2',]
    drop_cols=[ 'rfi_max', 'spl1_2.0', 'spl1_2.3', 'spl1_2.7', 'spl1_3.0', 'spl1_3.3', 'spl1_3.7', 'spl1_4.0', 'spl1_4.3', 'spl1_4.7', 'spl1_5.0', 'spl1_5.3', 'spl1_5.7', 'spl1_6.0', 'spl1_6.3', 'spl1_6.7', 'spl1_7.0', 'spl1_7.3', 'spl1_7.7', 'spl1_8.0', 'spl1_8.3', 'spl2_2.0', 'spl2_2.3', 'spl2_2.7', 'spl2_3.0', 'spl2_3.3', 'spl2_3.7', 'spl2_4.0', 'spl2_4.3', 'spl2_4.7', 'spl2_5.0', 'spl2_5.3', 'spl2_5.7', 'spl2_6.0', 'spl2_6.3', 'spl2_6.7', 'spl2_7.0', 'spl2_7.3', 'spl2_7.7', 'spl2_8.0', 'spl2_8.3', 'time2', 'lat_m', 'lon_m', 'elevation_m', 'occheight_m', 'slip_L1', 'slip_L2']
    drop_cols=[ 'rfi_max', 'spl1_2.0', 'spl1_2.3', 'spl1_2.7', 'spl1_3.0', 'spl1_3.3', 'spl1_3.7', 'spl1_4.0', 'spl1_4.3', 'spl1_4.7', 'spl1_5.0', 'spl1_5.3', 'spl1_5.7', 'spl1_6.0', 'spl1_6.3', 'spl1_6.7', 'spl1_7.0', 'spl1_7.3', 'spl1_7.7', 'spl1_8.0', 'spl1_8.3', 'spl2_2.0', 'spl2_2.3', 'spl2_2.7', 'spl2_3.0', 'spl2_3.3', 'spl2_3.7', 'spl2_4.0', 'spl2_4.3', 'spl2_4.7', 'spl2_5.0', 'spl2_5.3', 'spl2_5.7', 'spl2_6.0', 'spl2_6.3', 'spl2_6.7', 'spl2_7.0', 'spl2_7.3', 'spl2_7.7', 'spl2_8.0', 'spl2_8.3', 'time2', 'lon_m', 'elevation_m', 'slip_L1', 'slip_L2']
    df=df.drop(columns=drop_cols)

    #Drop low SNR?
    #if "y_" in df:
    #    df = df[df["y_"] != 9]

    # Drop nans, inf, etc
    df=df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

    times=df['time'].values
    lats=df["lat_m"].values
    occ_hts=df['occheight_m'].values
    X=df.loc[:, df.columns != 'y_'].drop(columns=['time', 'lat_m','occheight_m']).values
    feature_names=df.loc[:, df.columns != 'y_'].drop(columns=['time', 'lat_m','occheight_m']).columns
    if "y_" in df:
        y_og=df["y_"]
        y_=class_map_binary(y_og)
        #y_=y_og
    else:
        y_=np.empty(X.shape[1])*np.nan

    return X, y_, times, lats, occ_hts, feature_names

# %%
label_df=pd.read_pickle('../data/converted_labels.pkl')
label_df_t=label_df[label_df["labeled?"]==True]
fdf_li=[]
for i,row in enumerate(label_df_t.Filename):
    #print(row['c1'], row['c2'])
    fn="../data/feature_sets/%s.pkl" %row[7:-8]
    
    try:
        fdf=pd.read_pickle(fn)
        if fdf.shape[1]==64:
            fdf_li+=[fdf]
        else:
            print(fn, fdf.shape[1])
        #print(i)
    except:
        pass
full_fdf=pd.concat(fdf_li, axis=0, ignore_index=True)

X, y, times, lats, occ_hts, feature_names =df_2_Xy(full_fdf)

#---- split data
from sklearn.model_selection import train_test_split
X_train0, X_test0, y_train0, y_test0, lats_train, lats_test, hts_train, hts_test = train_test_split(X, y.ravel(), lats, occ_hts, test_size = 0.5, random_state = 20, stratify = y)
# Out:
# ../data/feature_sets/2023.144.103.21.01.R05.SC001_0001.pkl 63

# %%
# comms link df
label_df=pd.read_pickle('../data/converted_labels_comms.pkl')

label_df_t=label_df[label_df["labeled?"]==True]
fdf_li=[]
for i,row in enumerate(label_df_t.Filename):
    #print(row['c1'], row['c2'])
    fn="../data/feature_sets/%s.pkl" %row
    
    try:
        fdf=pd.read_pickle(fn)
        if fdf.shape[1]==64:
            fdf_li+=[fdf]
        else:
            print(fn, fdf.shape[1])
        #print(i)
    except:
        pass
comms_fdf=pd.concat(fdf_li, axis=0, ignore_index=True)

X, y, times, lats, occ_hts, feature_names =df_2_Xy(comms_fdf)

#---- split data
from sklearn.model_selection import train_test_split
X_trainC, X_testC, y_trainC, y_testC, lats_trainC, lats_testC, hts_trainC, hts_testC = train_test_split(X, y.ravel(), lats, occ_hts, test_size = 0.5, random_state = 20, stratify = y)

# %%
y_testC.shape
y_test0.shape
# Out:
# (4810,)

# %%
np.concatenate((y_test0,y_testC)).shape
# Out:
# (5468,)

# %%
a = np.array([1, 2, 3])

# %%
a.shape
# Out:
# (3,)

# %%
version="2-comms-test" # what does this mean?
print(X.shape, y.shape)
from collections import Counter
print("Class numbers check")
print(Counter(y.ravel()))


from sklearn.model_selection import GridSearchCV

#---- split data
# Split above!  Now merge comms and regular data:


#drop low snr from training but keep for testing!
#X_train=X_train[y_train!=9]
#y_train=y_train[y_train!=9]

# map to binary classes
#y_train=class_map_binary(y_train)
#y_test=class_map_binary(y_test)

def rf_model(X_train, y_train):
    #--- train models
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.pipeline import Pipeline
    from sklearn.preprocessing import StandardScaler
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('clf', RandomForestClassifier(random_state = 42))
    ])
    parameters = { 
        'clf__n_estimators': [1, 10, 100],
        'clf__max_features': ['auto', 'sqrt', 'log2'],
        'clf__max_depth' : [1,10,100, 1000],
        #'clf__criterion' : ['gini', 'entropy'],
        'clf__class_weight' : [None, 'balanced', 'balanced_subsample']
    }
    from sklearn.model_selection import GridSearchCV
    model = GridSearchCV(pipeline, param_grid = parameters, cv = 5, n_jobs=20, scoring="f1")
    model.fit(X_train, y_train)

    print("\nBest: %f using %s" % (model.best_score_, model.best_params_))
    means = model.cv_results_['mean_test_score']
    stds = model.cv_results_['std_test_score']
    params = model.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("      %f (%f) with: %r" % (mean, stdev, param))

    #-- Save model
    from joblib import dump, load
    #dump(model, '../models/%s_rf-model.joblib' %version)
    
    return model

def xgb_model(X_train, y_train):
    #--- train model
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.pipeline import Pipeline
    from sklearn.preprocessing import StandardScaler
    from xgboost import XGBClassifier

    estimator = XGBClassifier(
        objective= 'binary:logistic',
        nthread=4,
        seed=42
    )
    parameters = {
        'max_depth': range (2, 10, 1),
        'n_estimators': range(60, 220, 40),
        'learning_rate': [0.1, 0.01, 0.05]
    }
    
    model = GridSearchCV(estimator, param_grid = parameters, cv = 5, n_jobs=20, scoring="f1")
    model.fit(X_train, y_train)

    print("\nBest: %f using %s" % (model.best_score_, model.best_params_))
    means = model.cv_results_['mean_test_score']
    stds = model.cv_results_['std_test_score']
    params = model.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("      %f (%f) with: %r" % (mean, stdev, param))

    #-- Save model
    from joblib import dump, load
    dump(model, '../models/%s_xgb-model.joblib' %version)

    return model

def svc_model(X_train, y_train):
    from sklearn.svm import SVC 
    from sklearn.model_selection import GridSearchCV 
  
    # defining parameter range 
    param_grid = {'C': [0.1, 1, 10, 100, 1000],  
                'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
                'kernel': ['rbf']}  
    
    model = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3, cv = 5, n_jobs=20, scoring="f1") 
    # fitting the model for grid search 
    model.fit(X_train, y_train)
    print("\nBest: %f using %s" % (model.best_score_, model.best_params_))
    means = model.cv_results_['mean_test_score']
    stds = model.cv_results_['std_test_score']
    params = model.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("      %f (%f) with: %r" % (mean, stdev, param))

    #-- Save model
    from joblib import dump, load
    #dump(model, '/home/kawu4468-copy/trained_models/rf-model.joblib')

    return model
  
for comms_test in ["new"]: #"old", 
    if comms_test=="old":
        X_train=X_train0
        y_train=y_train0
    if comms_test=="new":
        X_train=np.vstack([X_train0,X_trainC])
        y_train=np.concatenate((y_train0,y_trainC))
    X_test=np.vstack([X_test0,X_testC])
    y_test=np.concatenate((y_test0,y_testC))

    print(comms_test," train shape: ", y_train.shape, " sum: ", y_train.sum())
    print(comms_test," test shape: ", y_test.shape, " sum: ", y_test.sum())

    rf_model=rf_model(X_train, y_train)
    xgb_model=xgb_model(X_train, y_train)
    svc_model=svc_model(X_train, y_train)

    for model in [rf_model, xgb_model, svc_model]:
        #--- test model
        y_pred = model.predict(X_test)

        from sklearn.metrics import classification_report, confusion_matrix
        from sklearn.metrics import precision_recall_fscore_support
        print("\nConfusion matrix")
        print(confusion_matrix(y_test, y_pred))
        y = y[~np.isnan(X).any(axis=1)]
        X = X[~np.isnan(X).any(axis=1)]
        print(X.shape, y.shape)
        print("\nResult")
        print(classification_report(y_test, y_pred))

        print(precision_recall_fscore_support(y_test, y_pred))
# Out:
# (1315, 14) (1315,)
# Class numbers check
# Counter({0.0: 793, 1.0: 522})
# new  train shape:  (5467,)  sum:  298.0
# new  test shape:  (5468,)  sum:  298.0
# Best: 0.755884 using {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.000000 (0.000000) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.096644 (0.193289) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.080620 (0.161240) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.000000 (0.000000) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.096644 (0.193289) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.080620 (0.161240) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.000000 (0.000000) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.096644 (0.193289) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.080620 (0.161240) with: {'clf__class_weight': None, 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.632768 (0.139550) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.705703 (0.185383) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.715624 (0.193504) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.632768 (0.139550) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.705703 (0.185383) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.715624 (0.193504) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.632768 (0.139550) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.705703 (0.185383) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.715624 (0.193504) with: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.599174 (0.145889) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.681285 (0.170761) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.702743 (0.186451) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.599174 (0.145889) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.681285 (0.170761) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.702743 (0.186451) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.599174 (0.145889) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.681285 (0.170761) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.702743 (0.186451) with: {'clf__class_weight': None, 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.599174 (0.145889) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.681285 (0.170761) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.702743 (0.186451) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.599174 (0.145889) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.681285 (0.170761) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.702743 (0.186451) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.599174 (0.145889) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.681285 (0.170761) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.702743 (0.186451) with: {'clf__class_weight': None, 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.273071 (0.082049) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.522731 (0.085182) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.497399 (0.104494) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.273071 (0.082049) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.522731 (0.085182) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.497399 (0.104494) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.273071 (0.082049) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.522731 (0.085182) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.497399 (0.104494) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.679773 (0.162141) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.737073 (0.196844) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.755884 (0.195879) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.679773 (0.162141) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.737073 (0.196844) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.755884 (0.195879) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.679773 (0.162141) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.737073 (0.196844) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.755884 (0.195879) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.650160 (0.147853) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.683106 (0.163410) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.702184 (0.183378) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.650160 (0.147853) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.683106 (0.163410) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.702184 (0.183378) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.650160 (0.147853) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.683106 (0.163410) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.702184 (0.183378) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.650160 (0.147853) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.683106 (0.163410) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.702184 (0.183378) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.650160 (0.147853) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.683106 (0.163410) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.702184 (0.183378) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.650160 (0.147853) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.683106 (0.163410) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.702184 (0.183378) with: {'clf__class_weight': 'balanced', 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.273071 (0.082049) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.522731 (0.085182) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.496664 (0.104699) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.273071 (0.082049) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.522731 (0.085182) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.496664 (0.104699) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.273071 (0.082049) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.522731 (0.085182) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.496664 (0.104699) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.706459 (0.192236) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.742534 (0.196015) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.751327 (0.191685) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.706459 (0.192236) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.742534 (0.196015) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.751327 (0.191685) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.706459 (0.192236) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.742534 (0.196015) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.751327 (0.191685) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.625349 (0.144405) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.685777 (0.172555) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.693174 (0.178959) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.625349 (0.144405) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.685777 (0.172555) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.693174 (0.178959) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.625349 (0.144405) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.685777 (0.172555) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.693174 (0.178959) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 100, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#       0.625349 (0.144405) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 1}
#       0.685777 (0.172555) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 10}
#       0.693174 (0.178959) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'auto', 'clf__n_estimators': 100}
#       0.625349 (0.144405) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 1}
#       0.685777 (0.172555) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 10}
#       0.693174 (0.178959) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'sqrt', 'clf__n_estimators': 100}
#       0.625349 (0.144405) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 1}
#       0.685777 (0.172555) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 10}
#       0.693174 (0.178959) with: {'clf__class_weight': 'balanced_subsample', 'clf__max_depth': 1000, 'clf__max_features': 'log2', 'clf__n_estimators': 100}
#
# Best: 0.726250 using {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}
#       0.665365 (0.157799) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 60}
#       0.689540 (0.177286) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
#       0.698138 (0.175040) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 140}
#       0.696992 (0.171592) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 180}
#       0.701691 (0.181682) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 60}
#       0.699345 (0.182407) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
#       0.710134 (0.193051) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 140}
#       0.708950 (0.194463) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 180}
#       0.708181 (0.191833) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 60}
#       0.705157 (0.189333) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100}
#       0.706037 (0.193203) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 140}
#       0.703804 (0.188059) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 180}
#       0.711961 (0.194221) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 60}
#       0.709509 (0.192922) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#       0.699585 (0.189370) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 140}
#       0.703511 (0.193459) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 180}
#       0.705400 (0.189492) with: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 60}
#       0.705697 (0.189929) with: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
#       0.700196 (0.188847) with: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 140}
#       0.714087 (0.191937) with: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 180}
#       0.710624 (0.195485) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 60}
#       0.708685 (0.186431) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
#       0.713685 (0.188976) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 140}
#       0.709371 (0.185919) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 180}
#       0.715506 (0.197732) with: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 60}
#       0.711204 (0.188409) with: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100}
#       0.708787 (0.186982) with: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 140}
#       0.698653 (0.186339) with: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 180}
#       0.707727 (0.182714) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 60}
#       0.704802 (0.182743) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 100}
#       0.707010 (0.184904) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 140}
#       0.703652 (0.188320) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 180}
#       0.701549 (0.162187) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 60}
#       0.695519 (0.166455) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100}
#       0.690282 (0.154574) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 140}
#       0.660045 (0.166942) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 180}
#       0.687623 (0.165219) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 60}
#       0.686898 (0.166103) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
#       0.700693 (0.178230) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 140}
#       0.695887 (0.179531) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 180}
#       0.698904 (0.178592) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 60}
#       0.696819 (0.172078) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 100}
#       0.705833 (0.181776) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 140}
#       0.713508 (0.190976) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 180}
#       0.702936 (0.178323) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 60}
#       0.704938 (0.180556) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}
#       0.709201 (0.184165) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 140}
#       0.713770 (0.186935) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 180}
#       0.720801 (0.181352) with: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 60}
#       0.715551 (0.187969) with: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
#       0.716838 (0.188929) with: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 140}
#       0.718735 (0.191080) with: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 180}
#       0.717410 (0.180899) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 60}
#       0.726250 (0.190571) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}
#       0.720246 (0.185522) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 140}
#       0.710929 (0.191708) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 180}
#       0.713183 (0.174653) with: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 60}
#       0.714610 (0.179302) with: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
#       0.718968 (0.181685) with: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 140}
#       0.707787 (0.187791) with: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 180}
#       0.708688 (0.172132) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 60}
#       0.711769 (0.176265) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 100}
#       0.718968 (0.181685) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 140}
#       0.709145 (0.189156) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 180}
#       0.654286 (0.163657) with: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 60}
#       0.653385 (0.164477) with: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100}
#       0.679005 (0.166970) with: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 140}
#       0.684069 (0.169503) with: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 180}
#       0.697584 (0.178641) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 60}
#       0.697144 (0.177677) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
#       0.701350 (0.185053) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 140}
#       0.700946 (0.185526) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 180}
#       0.712406 (0.188662) with: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 60}
#       0.710112 (0.193981) with: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100}
#       0.710131 (0.185717) with: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 140}
#       0.702683 (0.188314) with: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 180}
#       0.725116 (0.194519) with: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 60}
#       0.719399 (0.192774) with: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}
#       0.715758 (0.189804) with: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 140}
#       0.709195 (0.193849) with: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 180}
#       0.724097 (0.192937) with: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 60}
#       0.722569 (0.197520) with: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
#       0.714499 (0.198786) with: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 140}
#       0.710039 (0.195994) with: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 180}
#       0.712630 (0.194431) with: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 60}
#       0.708327 (0.194156) with: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 100}
#       0.709502 (0.192375) with: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 140}
#       0.707160 (0.191975) with: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 180}
#       0.710601 (0.190790) with: {'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 60}
#       0.708151 (0.194568) with: {'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100}
#       0.703744 (0.187411) with: {'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 140}
#       0.702847 (0.190002) with: {'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 180}
#       0.704111 (0.187458) with: {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 60}
#       0.700089 (0.188214) with: {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 100}
#       0.707481 (0.184151) with: {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 140}
#       0.709169 (0.186503) with: {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 180}
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.410 total time=   0.2s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.351 total time=   0.2s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.757 total time=   0.2s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.410 total time=   0.2s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.575 total time=   0.2s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.549 total time=   0.2s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.555 total time=   0.3s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.772 total time=   0.3s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.3s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.447 total time=   0.3s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.000 total time=   0.3s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.000 total time=   0.4s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.000 total time=   0.4s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.000 total time=   0.4s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.000 total time=   0.4s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.000 total time=   0.4s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.430 total time=   0.2s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.588 total time=   0.1s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.436 total time=   0.1s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.865 total time=   0.2s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.584 total time=   0.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.689 total time=   0.2s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.826 total time=   0.2s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.822 total time=   0.2s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.758 total time=   0.2s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.487 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.881 total time=   0.2s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.185 total time=   0.2s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.467 total time=   0.3s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.400 total time=   0.4s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.232 total time=   0.2s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.792 total time=   0.4s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.2s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.481 total time=   0.4s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.033 total time=   0.2s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.232 total time=   0.3s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.368 total time=   0.3s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.3s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.436 total time=   0.1s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.556 total time=   0.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.590 total time=   0.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.722 total time=   0.5s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.862 total time=   0.2s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.841 total time=   0.2s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.681 total time=   0.2s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.836 total time=   0.2s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.881 total time=   0.2s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.702 total time=   0.2s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.442 total time=   0.2s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.481 total time=   0.2s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.832 total time=   0.2s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.592 total time=   0.1s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.816 total time=   0.4s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.879 total time=   0.2s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.439 total time=   0.3s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.727 total time=   0.4s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.179 total time=   0.2s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.463 total time=   0.1s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.206 total time=   0.2s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.2s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.154 total time=   0.2s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.450 total time=   0.5s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.588 total time=   0.4s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.127 total time=   0.2s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.488 total time=   0.2s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.841 total time=   0.2s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.696 total time=   0.1s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.674 total time=   0.2s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.843 total time=   0.2s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.581 total time=   0.2s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.500 total time=   0.2s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.568 total time=   0.2s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.707 total time=   0.3s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.442 total time=   0.2s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.442 total time=   0.2s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.748 total time=   0.3s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.841 total time=   0.3s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.919 total time=   0.3s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.421 total time=   0.1s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.415 total time=   0.4s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.891 total time=   0.3s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.517 total time=   0.4s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.426 total time=   0.4s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.568 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.827 total time=   0.2s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.776 total time=   0.2s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.621 total time=   0.2s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.762 total time=   0.5s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.718 total time=   0.5s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.550 total time=   0.2s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.442 total time=   0.2s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.574 total time=   0.1s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.463 total time=   0.3s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.429 total time=   0.3s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.909 total time=   0.2s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.854 total time=   0.2s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.702 total time=   0.2s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.442 total time=   0.3s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.421 total time=   0.1s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.470 total time=   0.4s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.575 total time=   0.1s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.752 total time=   0.5s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.843 total time=   0.2s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.919 total time=   0.2s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.652 total time=   0.2s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.757 total time=   0.4s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.841 total time=   0.5s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.841 total time=   0.4s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.500 total time=   0.5s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.710 total time=   0.4s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.415 total time=   0.5s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.881 total time=   0.5s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.724 total time=   0.5s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.686 total time=   0.7s
#
# Best: 0.696323 using {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#       0.000000 (0.000000) with: {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
#       0.632279 (0.135416) with: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
#       0.466452 (0.083946) with: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
#       0.000000 (0.000000) with: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
#       0.000000 (0.000000) with: {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
#       0.572379 (0.154716) with: {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
#       0.679611 (0.158877) with: {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
#       0.696245 (0.163755) with: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
#       0.300729 (0.111519) with: {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#       0.006557 (0.013115) with: {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
#       0.604013 (0.149080) with: {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
#       0.683327 (0.150162) with: {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
#       0.689895 (0.163715) with: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
#       0.682026 (0.159510) with: {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#       0.225680 (0.121315) with: {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
#       0.567575 (0.145961) with: {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
#       0.656732 (0.139931) with: {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
#       0.683185 (0.167173) with: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
#       0.696132 (0.172752) with: {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
#       0.642445 (0.146124) with: {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
#       0.556355 (0.137739) with: {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
#       0.651030 (0.155283) with: {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#       0.684618 (0.167799) with: {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
#       0.696323 (0.173226) with: {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#       0.681901 (0.180343) with: {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# Confusion matrix
# [[5093   77]
#  [  37  261]]
# (1315, 14) (1315,)
#
# Result
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      5170
#          1.0       0.77      0.88      0.82       298
#
#     accuracy                           0.98      5468
#    macro avg       0.88      0.93      0.90      5468
# weighted avg       0.98      0.98      0.98      5468
#
# (array([0.99278752, 0.77218935]), array([0.98510638, 0.87583893]), array([0.98893204, 0.82075472]), array([5170,  298]))
#
# Confusion matrix
# [[5114   56]
#  [  61  237]]
# (1315, 14) (1315,)
#
# Result
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      5170
#          1.0       0.81      0.80      0.80       298
#
#     accuracy                           0.98      5468
#    macro avg       0.90      0.89      0.90      5468
# weighted avg       0.98      0.98      0.98      5468
#
# (array([0.98821256, 0.80887372]), array([0.98916828, 0.79530201]), array([0.98869019, 0.80203046]), array([5170,  298]))
#
# Confusion matrix
# [[5129   41]
#  [  90  208]]
# (1315, 14) (1315,)
#
# Result
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      5170
#          1.0       0.84      0.70      0.76       298
#
#     accuracy                           0.98      5468
#    macro avg       0.91      0.85      0.87      5468
# weighted avg       0.97      0.98      0.98      5468
#
# (array([0.98275532, 0.83534137]), array([0.99206963, 0.69798658]), array([0.98739051, 0.76051188]), array([5170,  298]))

# %%
results={"Before":
         {"Precision": {"Random Forest":0.8,
                       "XGBoost":0.67741935,
                       "SVM": 0.6},
         "Recall": {"Random Forest":0.05369128,
                       "XGBoost":0.0704698,
                       "SVM": 0.06040268},
         "F1":{"Random Forest":0.10062893,
                       "XGBoost":0.12765957,
                       "SVM": 0.1097561}
         },

        "After":
         {"Precision": {"Random Forest": 0.77218935,
                       "XGBoost":0.80887372,
                       "SVM": 0.83534137},
         "Recall": {"Random Forest":0.87583893,
                       "XGBoost":0.79530201,
                       "SVM": 0.69798658},
         "F1":{"Random Forest": 0.82075472,
                       "XGBoost":0.80203046,
                       "SVM": 0.76051188},
                       }
}

# %%
results
# Out:
# {'Before': {'Precision': {'Random Forest': 0.8,
#    'XGBoost': 0.67741935,
#    'SVM': 0.6},
#   'Recall': {'Random Forest': 0.05369128,
#    'XGBoost': 0.0704698,
#    'SVM': 0.06040268},
#   'F1': {'Random Forest': 0.10062893,
#    'XGBoost': 0.12765957,
#    'SVM': 0.1097561}},
#  'After': {'Precision': {'Random Forest': 0.77218935,
#    'XGBoost': 0.80887372,
#    'SVM': 0.83534137},
#   'Recall': {'Random Forest': 0.87583893,
#    'XGBoost': 0.79530201,
#    'SVM': 0.69798658},
#   'F1': {'Random Forest': 0.82075472,
#    'XGBoost': 0.80203046,
#    'SVM': 0.76051188}}}

# %%
resultsdf
# Out:
#        Random Forest                      XGBoost                      \
#                   F1 Precision    Recall       F1 Precision    Recall
# After       0.820755  0.772189  0.875839  0.80203  0.808874  0.795302
# Before      0.100629  0.800000  0.053691  0.12766  0.677419  0.070470
#
#              SVM
#               F1 Precision    Recall
# After   0.760512  0.835341  0.697987
# Before  0.109756  0.600000  0.060403

# %%
import pandas as pd
resultsdf=pd.DataFrame.from_dict({(i,j): results[i][j] 
                           for i in results.keys() 
                           for j in results[i].keys()},
                       orient='index')
resultsdf=resultsdf.unstack()

# %%
fig,ax=plt.subplots()
for modelp in ['Random Forest','XGBoost','SVM']:
    for indexp, metricp in enumerate(["Precision","Recall","F1"]):
        for colorp, timep in zip(["tab:green","tab:blue"],["Before","After"]):
            
            ax.bar(indexp, resultsdf[modelp][metricp][timep], color=colorp)

# %%
resultsdf[("Before","Precision")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Before', 'Precision')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_15065/2706881459.py in <module>
# ----> 1 resultsdf[("Before","Precision")]
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: ('Before', 'Precision')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Before'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_15065/1376936568.py in <module>
# ----> 1 resultsdf.unstack()["Before"]
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3455         if is_single_key:
#    3456             if self.columns.nlevels > 1:
# -> 3457                 return self._getitem_multilevel(key)
#    3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3506     def _getitem_multilevel(self, key):
#    3507         # self.columns is a MultiIndex
# -> 3508         loc = self.columns.get_loc(key)
#    3509         if isinstance(loc, (slice, np.ndarray)):
#    3510             new_columns = self.columns[loc]
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2920
#    2921         if not isinstance(key, tuple):
# -> 2922             loc = self._get_level_indexer(key, level=0)
#    2923             return _maybe_to_slice(loc)
#    2924
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3202         else:
#    3203
# -> 3204             idx = self._get_loc_single_level_index(level_index, key)
#    3205
#    3206             if level > 0 or self._lexsort_depth == 0:
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2853             return -1
#    2854         else:
# -> 2855             return level_index.get_loc(key)
#    2856
#    2857     def get_loc(self, key, method=None):
#
# ~/gnss-leo-data/.venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Before'

# %%
import matplotlib.pyplot as plt
import numpy as np
idx = pd.MultiIndex.from_product([['Before', 'After'], ['Precision', 'Recall', 'F1']], names=['Version', 'Metric'])
df = pd.DataFrame(np.random.randint(2, 10, size=(idx.size, 1)), index=idx, columns=['total bill'])
df.unstack(level=0)['total bill'].plot(
    kind='bar'
)
plt.ylabel('total bill');

# %%
resultsdf
# Out:
#                   Random Forest   XGBoost       SVM
# Before Precision       0.800000  0.677419  0.600000
#        Recall          0.053691  0.070470  0.060403
#        F1              0.100629  0.127660  0.109756
# After  Precision       0.772189  0.808874  0.835341
#        Recall          0.875839  0.795302  0.697987
#        F1              0.820755  0.802030  0.760512

# %%
#stdi2687/gnss-leo-data/figures/labeling_rfi/2023.016.135.20.01.G27.SC001_0001_features.png
sample='2023.143.125.17.01.R11.SC001_0001'
sample='2023.016.135.20.01.G27.SC001_0001'
sample='2023.057.135.20.01.G01.SC001_0001'
sample='2023.101.134.09.01.G25.SC001_0001'
sample='2022.321.135.22.01.G24.SC001_0001'

fn='/media/datastore/mirror/spwxdp/repro4/spire/level1b/scnPhs/%s/scnPhs_%s.0001_nc'%(sample[:8],sample)
lv1=load_leo(fn)
fn='/media/datastore/mirror/spwxdp/repro4/spire/level2/scnLv2/%s/scnLv2_%s.0001_nc'%(sample[:8],sample)
lv2=load_leo(fn)

#plot_leo(sample, sp, lv2)
fdf=extract_fs(lv1,lv2)

# %%
X, y_, times, lats, occ_hts, feature_names=df_2_Xy(fdf)
#--- test model
y_pred = xgb_model.predict(X)
print(y_pred)
# Out:
# [0 0 0 0 0 0 1 1 0 1]

# %%
from matplotlib.patches import Rectangle
def plot_leo_ml(sample, ds, lv2, y_pred, times):

    c=299792458 #m/s
    #iono_free=((ds.scnfreq1**2)*(c/ds['exL1'])-(ds.scnfreq2**2)*(c/ds['exL2']))/(ds.scnfreq1**2-ds.scnfreq2**2)
    
    #ku=40.3*1e16
    #dTEC=(ds['exL2']-ds['exL1'])/(ku*(1/ds.scnfreq1**2-1/ds.scnfreq2**2))
    fig,ax=plt.subplots(6, figsize=(8,8),sharex=True)
    ax[0].set_title(sample)

    for freq,snr,color in zip([1,2],['caL1Snr','pL2Snr'],['#1b9e77','#d95f02']): 
        ax[0].plot(ds[snr].time+ds.startTime, ds[snr].values, alpha=.5, color=color, label='L%s'%freq)
        ax[0].set_ylabel('SNR' "\n" '(v/v)')

        ax[1].plot(lv2['s4_L%s'%freq].time+lv2.startTime, lv2['s4_L%s'%freq].values, color=color)
        ax[1].set_ylabel('S4')
        
        #ax[1].plot(ds['raw_exL%s'%freq].time, ds['raw_exL%s'%freq].values, color=color, label='L%s'%freq)
        #ax[1].set_ylabel(r'$\delta \phi$ (cycles)')
        ax[4].plot(lv2['elevation'].time+lv2.startTime, lv2['elevation'].values, color='black')
        ax[4].set_ylabel('elevation')
        ax2=ax[4].twinx()
        ax2.plot(ds['occheight'].time+ds.startTime, ds['occheight'].values, color='tab:orange')
        ax2.set_ylabel('occ height', color='tab:orange')

            
        ax[2].plot(ds['exL%s'%freq].time+ds.startTime, ds['exL%s'%freq].values, color=color, label='L%s'%freq)
        ax[2].set_ylabel(r'$\delta \phi$' "\n" '(m)')

        ax[3].plot(lv2['sigma_phi_L%s'%freq].time+lv2.startTime, lv2['sigma_phi_L%s'%freq].values, color=color)
        ax[3].set_ylabel(r'$\sigma \phi$' "\n" '(m)')
    #ax[3].plot(dTEC.time, dTEC.values)
    
    #ax[3].set_ylabel(r'$\Delta TEC$' "\n" '(TECU)')
    
    #ax[4].plot(iono_free.time, iono_free.values)
    #ax[4].set_ylabel('iono-free' "\n" '(m)')
    ax[0].legend(ncol=2)
    '''
    ## plot ml results
    df=pd.read_pickle('/home/kawu4468-copy/data_mat/spire_iq/rf_ml_ro.pkl')
    colors=['#e7298a','#d95f02','#7570b3','#1b9e77','#1b9e77','#66a61e','#e6ab02'] ##1b9e77
    labels=['scint', 'OA', 'dual int', 'quiet', 'quiet', 'l1 int', 'l2 int']
    fn_arr='scnPhs_%s.0001_ex.mat' %sample
    df=df[df.file==fn_arr]
    print(df['sample'])
    print(df.y_pred)
    [ax[5].add_patch(Rectangle((ds.time.min()+i*15, 0), 15, 1, alpha=.75, color= ,  label=labels[y-1])) for i, y in list(zip(df['sample'], df.y_pred))]
    '''
    [ax[5].add_patch(Rectangle((i, 0), 15, 1, alpha=1, label='No RFI', color="white")) for i in times[y_pred==0]]
    [ax[5].axvline(i) for i in times]
    [ax[5].add_patch(Rectangle((i, 0), 15, 1, alpha=.75, label='RFI')) for i in times[y_pred>0]]
    
    handles,labels=ax[5].get_legend_handles_labels() #get existing legend item handles and labels
    by_label = dict(zip(labels, handles))
    ax[5].legend(by_label.values(), by_label.keys(), ncol=4, loc='lower left')
    ax[5].get_yaxis().set_ticks([])
    ax[5].set_ylabel('RF Class')

    ax[5].set_xlim([times.min(), times.max()])

    ax2=ax[5].twinx()
    ax2.plot(ds['RFI'].orbtime-ds['RFI'].orbtime[0]+ds.startTime, ds['RFI'].values, color='tab:orange')
    #ax2.plot(hour_init+(ds['RFI'].orbtime-ds.startTime.values[0])/3600, ds['RFI'].values)
    ax2.set_ylabel('RFI')
    #plt.savefig("../figures/results/%s.png" %sample, dpi=300)

# %%
plot_leo_ml(sample, lv1, lv2, y_pred, times)
